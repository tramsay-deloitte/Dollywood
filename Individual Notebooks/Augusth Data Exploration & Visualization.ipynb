# %% [markdown]
# # Semester 1 Project Submission
#
# Please fill out:
# * Student name: Augusth Koppal
# * Instructor name: Nick & Julian

# %% [markdown]
# ### Imported the necessary packages to clean and visualize data

# %%
import pandas as pd
import sqlite3
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Mission Statement: Movie performance according to time of the year

# %% [markdown]
# ### TMDB Movies dataframe from CSV file

# %%
df_4 = pd.read_csv('zippedData/tmdb.movies.csv.gz')
df_4
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
score = df_4["vote_average"]
score
#dropped all 0.0 values from vote_average score
# Out:
# 0        7.7
# 1        7.7
# 2        6.8
# 3        7.9
# 4        8.3
#         ...
# 26512    0.0
# 26513    0.0
# 26514    0.0
# 26515    0.0
# 26516    0.0
# Name: vote_average, Length: 26517, dtype: float64

# %%
df_4 = df_4.loc[~((df_4['vote_average'] == 0.0))]
df_4
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26500       26500                   []  561932                en
# 26501       26501                 [27]  558305                en
# 26502       26502                 [16]  551756                en
# 26503       26503                 [99]  543481                de
# 26504       26504         [27, 35, 27]  534282                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26500                                           Two       0.600   2018-02-04
# 26501                                President Evil       0.600   2018-10-18
# 26502           Vicktey Vitch (It's Halloween Poem)       0.600   2018-10-01
# 26503                                  Evolution 4K       0.600   2018-06-12
# 26504                                          Head       0.600   2015-03-28
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26500                                           Two           1.0           1
# 26501                                President Evil           1.0           1
# 26502           Vicktey Vitch (It's Halloween Poem)           1.0           1
# 26503                                  Evolution 4K           1.0           1
# 26504                                          Head           1.0           1
#
# [26381 rows x 10 columns]

# %%
#plot scatter chart showing distribution

# %%
df_4newvc = df_4.loc[df_4.vote_count>2500]

# %%
df_4newvc
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 23970       23970      [35, 18, 10749]  449176                en
# 23971       23971             [18, 36]  446354                en
# 23973       23973                 [18]  389015                en
# 23975       23975             [18, 36]  399404                en
# 24005       24005             [27, 53]  346364                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 23970                                   Love, Simon      15.608   2018-03-16
# 23971                                      The Post      15.551   2017-12-22
# 23973                                      I, Tonya      15.407   2017-12-08
# 23975                                  Darkest Hour      15.331   2017-11-22
# 24005                                            It      13.966   2017-09-08
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 23970                                   Love, Simon           8.2        3165
# 23971                                      The Post           7.0        2506
# 23973                                      I, Tonya           7.5        2904
# 23975                                  Darkest Hour           7.3        2715
# 24005                                            It           7.2       10931
#
# [547 rows x 10 columns]

# %%
df_4newvc.plot.scatter(x='vote_average', y='vote_count', title= "Scatter plot between vote_average & vote_count");

# %% [markdown]
# ### Created Movie Budgets dataframe from CSV file

# %%
df_5 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df_5.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#drop commas and $ for domestic_gross & worldwide_gross
df_5['domestic_gross'].dtypes


df_5['domestic_gross'] = df_5['domestic_gross'].str.replace(',', '')
df_5['domestic_gross'] = df_5['domestic_gross'].str.replace('$', '')
df_5['domestic_gross']

df_5['domestic_gross'] = pd.to_numeric(df_5['domestic_gross'])

# %%
type(df_5['domestic_gross'][0])
# Out:
# numpy.int64

# %%
#drop commas and $ for worldwide_gross
df_5['worldwide_gross'].dtypes


df_5['worldwide_gross'] = df_5['worldwide_gross'].str.replace(',', '')
df_5['worldwide_gross'] = df_5['worldwide_gross'].str.replace('$', '')
df_5['worldwide_gross']

df_5['worldwide_gross'] = pd.to_numeric(df_5['worldwide_gross'])

# %%
#drop years and month date for release_date
df_5.month = df_5['release_date'].map(lambda x: x[:3])
df_5.month
# Out:
# 0       Dec
# 1       May
# 2       Jun
# 3       May
# 4       Dec
#        ...
# 5777    Dec
# 5778    Apr
# 5779    Jul
# 5780    Sep
# 5781    Aug
# Name: release_date, Length: 5782, dtype: object

# %%
#divide release_date by 12 months

df_5.splitmonths = df_5.month.replace(to_replace={
    "Jan":1,
    "Feb":2,
    "Mar":3,
    "Apr":4,
    "May":5,
    "Jun":6,
    "Jul":7,
    "Aug":8,
    "Sep":9,
    "Oct":10,
    "Nov":11,
    "Dec":12
})

#replace method?

# %%
df_5.splitmonths
# Out:
# 0       12
# 1        5
# 2        6
# 3        5
# 4       12
#         ..
# 5777    12
# 5778     4
# 5779     7
# 5780     9
# 5781     8
# Name: release_date, Length: 5782, dtype: int64

# %%
df_5.splitmonths.dropna()
# Out:
# 0       12
# 1        5
# 2        6
# 3        5
# 4       12
#         ..
# 5777    12
# 5778     4
# 5779     7
# 5780     9
# 5781     8
# Name: release_date, Length: 5782, dtype: int64

# %%
df_5.splitmonths.value_counts()
# Out:
# 12    745
# 10    573
# 8     496
# 9     493
# 11    486
# 6     479
# 3     470
# 4     454
# 7     440
# 5     407
# 2     392
# 1     347
# Name: release_date, dtype: int64

# %%
df_5.splitmonths.unique()
# Out:
# array([12,  5,  6,  4, 11,  7,  3,  2, 10,  8,  9,  1], dtype=int64)

# %%
df_5['splitmonths'] = df_5.splitmonths

# %%
df_5.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  splitmonths
# 0      $425,000,000      760507625      2776345279           12
# 1      $410,600,000      241063875      1045663875            5
# 2      $350,000,000       42762350       149762350            6
# 3      $330,600,000      459005868      1403013963            5
# 4      $317,000,000      620181382      1316721747           12

# %%
df_5['worldwide_gross']
df_5.worldwide_gross.value_counts()
# Out:
# 0            367
# 8000000        9
# 7000000        6
# 2000000        6
# 11000000       4
#             ...
# 1641788        1
# 150350000      1
# 49037621       1
# 12179708       1
# 207039844      1
# Name: worldwide_gross, Length: 5356, dtype: int64

# %%
# #plot domestic_gross & worldwide_gross totals by months

# fig, ax = plt.subplots(figsize=(12, 8))

# # Define bar width. We'll use this to offset the second bar.
# bar_width = 0.4

# # Note we add the `width` parameter now which sets the width of each bar.
# b1 = ax.bar(df_5.splitmonths, df_5['domestic_gross'])
# # Same thing, but offset the x by the width of the bar.
# b2 = ax.bar(df_5.splitmonths, df_5['worldwide_gross'])

# %%
sns.set(style='white')

#create grouped bar chart
sns.barplot(x=df_5.splitmonths, y=df_5.domestic_gross, data=df_5)
# Out:
# <AxesSubplot:xlabel='release_date', ylabel='domestic_gross'>

# %%
sns.barplot(x=df_5.splitmonths, y=df_5.worldwide_gross, data=df_5)
# Out:
# <AxesSubplot:xlabel='release_date', ylabel='worldwide_gross'>
