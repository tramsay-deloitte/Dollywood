# %% [markdown]
# https://www2.deloitte.com/us/en/insights/industry/technology/future-of-the-movie-industry.html

# %% [markdown]
# ### Potential advantages or disadvantages for studios
#
# 1. theatres vs streaming directly
# 2. First 17 days of box office are crucial
# 3. longer a movie runs in theatres the more venues make and less that studios make
# 4. License fees are dependent on box office revenue
# 5. tv deals are are a potential additional source but require min box office revenue
# 6. Studios are relucatant to join digital services becuase of adverse affect on existing agreements(distribution, etc.)

# %% [markdown]
# https://www.rklesolutions.com/hubfs/RKL_eSolutions_Entertainment_eBook.pdf

# %% [markdown]
# 1. Automate business processes to increase productivity
# 2. Empower teams with visibility into performance
# 3. Connect data across best-in-class applications
# 4. Remove the distractions of IT
# 5. Work with a partner who knows your industry

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
# imdb_movie_basics = pd.read_sql_query("SELECT * FROM movie_basics", conn)
# imdb_movie_basics.head()

# %%
# imdb_movie_ratings = pd.read_sql_query("SELECT * FROM movie_ratings", conn)
# imdb_movie_ratings.head()

# %%
bom_movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross.year.head()
# Out:
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# Name: year, dtype: int64

# %%
rt_movies_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep = '\t')
rt_movies_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_movies_info.dropna(inplace = True)

# %%
rt_movies_info['theater_date'].head()
# Out:
# 1     Aug 17, 2012
# 6     Jan 11, 2002
# 7     Apr 27, 2006
# 15    Dec 17, 2010
# 18    Dec 25, 2013
# Name: theater_date, dtype: object

# %%
rt_movies_info['year'] = rt_movies_info.theater_date
rt_movies_info.head()
# Out:
#     id                                           synopsis rating  \
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
#
#                                                 genre             director  \
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
#
#                               writer  theater_date      dvd_date currency  \
# 1       David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 6                         Mike White  Jan 11, 2002  Jun 18, 2002        $
# 7   Raymond Carver|Beatrix Christian  Apr 27, 2006   Oct 2, 2007        $
# 15                     Norman Snider  Dec 17, 2010   Apr 5, 2011        $
# 18        Chris Morgan|Hossein Amini  Dec 25, 2013   Apr 1, 2014        $
#
#     box_office      runtime                  studio          year
# 1      600,000  108 minutes       Entertainment One  Aug 17, 2012
# 6   41,032,915   82 minutes      Paramount Pictures  Jan 11, 2002
# 7      224,114  123 minutes  Sony Pictures Classics  Apr 27, 2006
# 15   1,039,869  108 minutes            ATO Pictures  Dec 17, 2010
# 18  20,518,224  127 minutes      Universal Pictures  Dec 25, 2013

# %%
rt_movies_info.year = rt_movies_info.year.map(lambda x: x[-4:])

# %%
rt_movies_info.year = rt_movies_info.year.astype('int64')

# %%
rt_movies_info.year.head()
# Out:
# 1     2012
# 6     2002
# 7     2006
# 15    2010
# 18    2013
# Name: year, dtype: int64

# %% [markdown]
# # Merge the Tables by Year

# %%
merge_df = rt_movies_info.merge(bom_movie_gross, how = 'outer', left_on = 'year', right_on = 'year')

# %%
merge_df
# Out:
#         id                                           synopsis rating  \
# 0      3.0  New York City, not-too-distant-future: Eric Pa...      R
# 1      3.0  New York City, not-too-distant-future: Eric Pa...      R
# 2      3.0  New York City, not-too-distant-future: Eric Pa...      R
# 3      3.0  New York City, not-too-distant-future: Eric Pa...      R
# 4      3.0  New York City, not-too-distant-future: Eric Pa...      R
# ...    ...                                                ...    ...
# 38177  NaN                                                NaN    NaN
# 38178  NaN                                                NaN    NaN
# 38179  NaN                                                NaN    NaN
# 38180  NaN                                                NaN    NaN
# 38181  NaN                                                NaN    NaN
#
#                                    genre          director  \
# 0      Drama|Science Fiction and Fantasy  David Cronenberg
# 1      Drama|Science Fiction and Fantasy  David Cronenberg
# 2      Drama|Science Fiction and Fantasy  David Cronenberg
# 3      Drama|Science Fiction and Fantasy  David Cronenberg
# 4      Drama|Science Fiction and Fantasy  David Cronenberg
# ...                                  ...               ...
# 38177                                NaN               NaN
# 38178                                NaN               NaN
# 38179                                NaN               NaN
# 38180                                NaN               NaN
# 38181                                NaN               NaN
#
#                              writer  theater_date     dvd_date currency  \
# 0      David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 1      David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 2      David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 3      David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 4      David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# ...                             ...           ...          ...      ...
# 38177                           NaN           NaN          NaN      NaN
# 38178                           NaN           NaN          NaN      NaN
# 38179                           NaN           NaN          NaN      NaN
# 38180                           NaN           NaN          NaN      NaN
# 38181                           NaN           NaN          NaN      NaN
#
#        box_office      runtime           studio_x  year  \
# 0        600000.0  108 minutes  Entertainment One  2012
# 1        600000.0  108 minutes  Entertainment One  2012
# 2        600000.0  108 minutes  Entertainment One  2012
# 3        600000.0  108 minutes  Entertainment One  2012
# 4        600000.0  108 minutes  Entertainment One  2012
# ...           ...          ...                ...   ...
# 38177         NaN          NaN                NaN  2018
# 38178         NaN          NaN                NaN  2018
# 38179         NaN          NaN                NaN  2018
# 38180         NaN          NaN                NaN  2018
# 38181         NaN          NaN                NaN  2018
#
#                                    title    studio_y  domestic_gross  \
# 0                  Marvel's The Avengers          BV     623400000.0
# 1                                Skyfall        Sony     304400000.0
# 2                  The Dark Knight Rises          WB     448100000.0
# 3      The Hobbit: An Unexpected Journey     WB (NL)     303000000.0
# 4             Ice Age: Continental Drift         Fox     161300000.0
# ...                                  ...         ...             ...
# 38177                          The Quake       Magn.          6200.0
# 38178        Edward II (2018 re-release)          FM          4800.0
# 38179                           El Pacto        Sony          2500.0
# 38180                           The Swan  Synergetic          2400.0
# 38181                  An Actor Prepares       Grav.          1700.0
#
#       foreign_gross
# 0         895500000
# 1         804200000
# 2         636800000
# 3         718100000
# 4         715900000
# ...             ...
# 38177           NaN
# 38178           NaN
# 38179           NaN
# 38180           NaN
# 38181           NaN
#
# [38182 rows x 17 columns]

# %%
rt_movies_info
# Out:
#         id                                           synopsis rating  \
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 6       10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7       13  Stewart Kane, an Irishman living in the Austra...      R
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 18      25  From ancient Japan's most enduring tale, the e...  PG-13
# ...    ...                                                ...    ...
# 1530  1968  This holiday season, acclaimed filmmaker Camer...     PG
# 1537  1976  Embrace of the Serpent features the encounter,...     NR
# 1541  1980  A band of renegades on the run in outer space ...  PG-13
# 1542  1981  Money, Fame and the Knowledge of English. In I...     NR
# 1545  1985  A woman who joins the undead against her will ...      R
#
#                                                   genre             director  \
# 1                     Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                                Comedy          Jake Kasdan
# 7                                                 Drama         Ray Lawrence
# 15                    Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 18    Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
# ...                                                 ...                  ...
# 1530                                       Comedy|Drama        Cameron Crowe
# 1537   Action and Adventure|Art House and International          Ciro Guerra
# 1541   Action and Adventure|Science Fiction and Fantasy          Joss Whedon
# 1542                                       Comedy|Drama         Gauri Shinde
# 1545                        Horror|Mystery and Suspense  Sebastian Gutierrez
#
#                                     writer  theater_date      dvd_date  \
# 1             David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013
# 6                               Mike White  Jan 11, 2002  Jun 18, 2002
# 7         Raymond Carver|Beatrix Christian  Apr 27, 2006   Oct 2, 2007
# 15                           Norman Snider  Dec 17, 2010   Apr 5, 2011
# 18              Chris Morgan|Hossein Amini  Dec 25, 2013   Apr 1, 2014
# ...                                    ...           ...           ...
# 1530     Aline Brosh McKenna|Cameron Crowe  Dec 23, 2011   Apr 3, 2012
# 1537  Ciro Guerra|Jacques Toulemonde Vidal  Feb 17, 2016  Jun 21, 2016
# 1541                           Joss Whedon  Sep 30, 2005  Dec 20, 2005
# 1542                          Gauri Shinde   Oct 5, 2012  Nov 20, 2012
# 1545                   Sebastian Gutierrez   Jun 1, 2007   Oct 9, 2007
#
#      currency  box_office      runtime                  studio  year
# 1           $     600,000  108 minutes       Entertainment One  2012
# 6           $  41,032,915   82 minutes      Paramount Pictures  2002
# 7           $     224,114  123 minutes  Sony Pictures Classics  2006
# 15          $   1,039,869  108 minutes            ATO Pictures  2010
# 18          $  20,518,224  127 minutes      Universal Pictures  2013
# ...       ...         ...          ...                     ...   ...
# 1530        $  72,700,000  126 minutes        20th Century Fox  2011
# 1537        $   1,320,005  123 minutes           Buffalo Films  2016
# 1541        $  25,335,935  119 minutes      Universal Pictures  2005
# 1542        $   1,416,189  129 minutes      Eros Entertainment  2012
# 1545        $      59,371   98 minutes        IDP Distribution  2007
#
# [235 rows x 13 columns]

# %%
rt_movies_info.studio.value_counts()
# Out:
# Universal Pictures       23
# Paramount Pictures       15
# 20th Century Fox         12
# Sony Pictures            12
# Warner Bros. Pictures    11
#                          ..
# Universal                 1
# USA Films                 1
# Independent Pictures      1
# Apparition Films          1
# Screen Gems               1
# Name: studio, Length: 101, dtype: int64

# %%
rt_movies_info.studio.unique()
# Out:
# array(['Entertainment One', 'Paramount Pictures',
#        'Sony Pictures Classics', 'ATO Pictures', 'Universal Pictures',
#        'MGM', 'Lions Gate Films', 'New Line Cinema',
#        'Samuel Goldwyn Films', 'Open Road Films', 'Roadside Attractions',
#        'Buena Vista Distribution Compa', 'Paramount Studios',
#        '20th Century Fox', 'Fine Line Features', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Dreamworks Pictures', 'Film District',
#        'Reliance Entertainment', 'WARNER BROTHERS PICTURES',
#        'DreamWorks SKG', 'Focus Features', 'IFC Films',
#        'The Weinstein Company', 'Lions Gate Films Inc.',
#        'Lionsgate Films', 'Magnolia Pictures', 'Sony Pictures',
#        'Sony Classics', 'Wrekin Hill Entertainment', 'Weinstein Company',
#        'Sony Pictures/TriStar Pictures', 'Aspiration Media',
#        'Variance Films', 'MGM/UA', 'Film Foundry Releasing',
#        'Walt Disney Pictures', 'Fox Searchlight Pictures', 'CBS Films',
#        'Echolight Studios', 'Lionsgate/Roadside Attractions',
#        'Sony Pictures/Columbia', 'Paramount Vantage', 'WB',
#        'Monterey Media', 'Screen Gems/SONY PICTURES',
#        'Sony Pictures Entertainment', 'Independent Pictures',
#        'Fox Searchlight', 'Cohen Media Group', 'Broad Green Pictures',
#        'Lionsgate Films/After Dark Films', 'First Independent Pictures',
#        'Indican Pictures', 'A24 Films', 'United Artists Pictures/MGM',
#        'Newmarket Film Group', 'Warner Bros.', 'Summit Entertainment',
#        'Paramount', 'United Artists Pictures', 'Lions Gate',
#        'Tribeca Film', 'Destination Film', 'Relativity Media',
#        'Touchstone Pictures', 'Lakeshore Entertainment',
#        'The Weinstein Co.', 'Buena Vista', 'Lorber Films', 'Screen Gems',
#        'Sony Pictures/Columbia Pictures', 'Universal', 'A24',
#        'Dimension Films', 'Fingerprint Releasing / Bleecker Street',
#        'Universal Pictures Distributio', 'Dreamworks/Paramount',
#        'Destination Films', 'Overture Films', 'Regent Releasing',
#        'IFC First Take', 'First Run Features', 'Film 44', 'Lionsgate',
#        'The Film Arcade', 'Universal Studios', 'Crane Movie Company',
#        'STX Entertainment', 'Phase 4 Films', 'Miramax Films',
#        'Apparition Films', 'Summit Premiere', 'TriStar Pictures',
#        'Weinstein Co.', 'Sony Pictures Releasing', 'USA Films',
#        'Buffalo Films', 'Eros Entertainment', 'IDP Distribution'],
#       dtype=object)

# %%
rt_movies_info.year.value_counts()
# Out:
# 2010    18
# 2004    18
# 2007    17
# 2006    17
# 2013    16
# 2009    16
# 2012    15
# 2011    14
# 2005    14
# 2003    14
# 2002    14
# 2016    11
# 2008    10
# 2001     9
# 2015     9
# 2014     9
# 2017     7
# 2000     5
# 1993     1
# 1974     1
# Name: year, dtype: int64

# %%
#line chart of most movies developed by studio each year

# %%
pd.Series(rt_movies_info['studio'].value_counts()).index[0:10].tolist()
# Out:
# ['Universal Pictures',
#  'Paramount Pictures',
#  '20th Century Fox',
#  'Sony Pictures',
#  'Warner Bros. Pictures',
#  'Sony Pictures Classics',
#  'IFC Films',
#  'New Line Cinema',
#  'Lionsgate Films',
#  'Columbia Pictures']

# %%
top_10 = pd.Series(rt_movies_info['studio'].value_counts()).index[0:10].tolist()

# %%
sns.lineplot(x=rt_movies_info.year, y=top_10)
plt.title('Most Movies Developed by Studio each Year')
plt.xlabel('Year')
plt.ylabel('Studio')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-ac32b166d3d7> in <module>
# ----> 1 sns.lineplot(x=rt_movies_info.year, y=top_10)
#       2 plt.title('Most Movies Developed by Studio each Year')
#       3 plt.xlabel('Year')
#       4 plt.ylabel('Studio')
#       5 plt.show()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     676
#     677     variables = _LinePlotter.get_semantics(locals())
# --> 678     p = _LinePlotter(
#     679         data=data, variables=variables,
#     680         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     409                         f"length {len(index)}"
#     410                     )
# --> 411                     raise ValueError(msg)
#     412             else:
#     413                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 10 does not match index length 235

# %%
sns.barplot(x=rt_movies_info.year, y=rt_movies_info.studio)
plt.title('Most Movies Developed by Studio each Year')
plt.xlabel('Year')
plt.ylabel('Studio')
plt.show()

# %%
rt_movies_info.head()
# Out:
#     id                                           synopsis rating  \
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
#
#                                                 genre             director  \
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
#
#                               writer  theater_date      dvd_date currency  \
# 1       David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 6                         Mike White  Jan 11, 2002  Jun 18, 2002        $
# 7   Raymond Carver|Beatrix Christian  Apr 27, 2006   Oct 2, 2007        $
# 15                     Norman Snider  Dec 17, 2010   Apr 5, 2011        $
# 18        Chris Morgan|Hossein Amini  Dec 25, 2013   Apr 1, 2014        $
#
#     box_office      runtime                  studio  year
# 1       600000  108 minutes       Entertainment One  2012
# 6     41032915   82 minutes      Paramount Pictures  2002
# 7       224114  123 minutes  Sony Pictures Classics  2006
# 15     1039869  108 minutes            ATO Pictures  2010
# 18    20518224  127 minutes      Universal Pictures  2013

# %%
# total box office revenue by each studio

# %%
#drop commas for box_office

rt_movies_info['box_office'].dtypes


rt_movies_info['box_office'] = rt_movies_info['box_office'].str.replace(',', '')
rt_movies_info['box_office']

rt_movies_info['box_office'] = pd.to_numeric(rt_movies_info['box_office'])

# %%
rt_movies_info['box_office']
# Out:
# 1         600000
# 6       41032915
# 7         224114
# 15       1039869
# 18      20518224
#           ...
# 1530    72700000
# 1537     1320005
# 1541    25335935
# 1542     1416189
# 1545       59371
# Name: box_office, Length: 235, dtype: int64

# %%
# create new df to plot
# brs_1 = pd.rt_movies_info().assign(Box_Office=df['box_office'], Studio=df['studio'])
# print(brs_1)

# %%
# #set seaborn plotting aesthetics
# sns.set(style='white')
# #create stacked bar chart
# rt_movies_info.set_index(['year']).plot(kind='bar', stacked=True, color=['steelblue', 'red'])

# #add overall title
# plt.title('Box Office Revenue by Studio', fontsize=16)

# #add axis titles
# plt.xlabel('Studio')
# plt.ylabel('Box Office Revenue')

# #rotate x-axis labels
# plt.xticks(rotation=45)

# %%
#top studios that performed domestic and foreign
#join table with
